# %% [markdown]
# <a href="https://colab.research.google.com/github/rai-sandeep/ai-colab-notebooks/blob/main/CreateDataset.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install -q -U datasets
# !huggingface-cli login --token <ENTER-HUGGINGFACE-TOKEN-HERE>
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 486.2/486.2 kB 13.2 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 110.5/110.5 kB 9.8 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 212.5/212.5 kB 16.4 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 134.3/134.3 kB 12.4 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 236.8/236.8 kB 22.2 MB/s eta 0:00:00
# Token will not been saved to git credential helper. Pass `add_to_git_credential=True` if you want to set the git credential as well.
# Token is valid (permission: write).
# Your token has been saved to /root/.cache/huggingface/token
# Login successful

# %%
from datasets import load_dataset
dataset = load_dataset("csv", data_files="/content/sample_data/data_set.csv")

rows_sel=dataset['train'].select(range(1))
rows_sel['answer']
# Out:
# Downloading and preparing dataset csv/default to /root/.cache/huggingface/datasets/csv/default-90af6f973036605f/0.0.0/eea64c71ca8b46dd3f537ed218fc9bf495d5707789152eb2764f5c78fa66d59d...
# Downloading data files:   0%|          | 0/1 [00:00<?, ?it/s]
# Extracting data files:   0%|          | 0/1 [00:00<?, ?it/s]
# Generating train split: 0 examples [00:00, ? examples/s]
# Dataset csv downloaded and prepared to /root/.cache/huggingface/datasets/csv/default-90af6f973036605f/0.0.0/eea64c71ca8b46dd3f537ed218fc9bf495d5707789152eb2764f5c78fa66d59d. Subsequent calls will reuse this data.
#   0%|          | 0/1 [00:00<?, ?it/s]
# ['# Abstract\\n\\nThe Rise of E-commerce\\n\\nE-commerce has revolutionized the way we shop and do business. With the advent of the internet, online retail platforms have gained immense popularity, offering convenience and a wide range of products to consumers. This white paper aims to explore the growth and impact of e-commerce on the global market.\\n\\n## Findings\\n\\n1. E-commerce has experienced exponential growth in recent years, with increasing numbers of consumers turning to online shopping.\\n2. The convenience of e-commerce has contributed to its popularity, allowing consumers to shop anytime and anywhere, from the comfort of their homes.\\n3. The global reach of e-commerce has opened up new opportunities for businesses to expand their customer base and increase sales.\\n\\n## Conclusion\\n\\nE-commerce is here to stay, and its influence will continue to shape the future of retail. As technology advances and consumer behavior evolves, businesses must adapt to the changing landscape and embrace e-commerce as a key driver of growth.']

# %%
dataset.push_to_hub("rai-sandeep/test_ds_1")
# Out:
# WARNING:datasets.dataset_dict:Pushing split train to the Hub.
# Pushing dataset shards to the dataset hub:   0%|          | 0/1 [00:00<?, ?it/s]
# Creating parquet from Arrow format:   0%|          | 0/1 [00:00<?, ?ba/s]
# Upload 1 LFS files:   0%|          | 0/1 [00:00<?, ?it/s]
